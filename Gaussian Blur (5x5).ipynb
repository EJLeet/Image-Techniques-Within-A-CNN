# %%
# import required libraries
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import time

# Import mlcompute module to use the optional set_mlc_device API for device selection with ML Compute.
from tensorflow.python.compiler.mlcompute import mlcompute

# Select processing device.
mlcompute.set_mlc_device(device_name='gpu') # Available options are 'cpu', 'gpu', and 'any'.

# Remove apple to tensorflow comparison warnings
# note these warning do not affect the model, they are removed for visual purposes
tf.autograph.set_verbosity(0)
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
# Out:
# WARNING:tensorflow:Eager mode uses the CPU. Switching to the CPU.

# %%
# measure time taken for model to run and to run image technique
start = time.time()

# %%
# download dataset and initialise test/train
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# apply image technique to dataset
gauss_train = np.empty((50000, 32, 32, 3))
gauss_test = np.empty((10000, 32, 32, 3))

for index, image in enumerate(train_images):
    gauss_train[index] = cv.GaussianBlur(image, (5,5), 0)

for index, image in enumerate(test_images):
    gauss_test[index] = cv.GaussianBlur(image, (5,5), 0)

# %%
# verify data
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

image_class_index = [gauss_train[30], gauss_train[5], gauss_train[6], gauss_train[9], gauss_train[3],
                     gauss_train[27], gauss_train[0], gauss_train[7], gauss_train[8], gauss_train[1]]

plt.figure(figsize=(10,10))
for i in range(len(image_class_index)):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image_class_index[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[i])
plt.show()

# %%
# import model
model = models.load_model("CNN")

# compile and train model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'], run_eagerly=False)

history = model.fit(gauss_train, train_labels, epochs=10, 
                    validation_data=(gauss_test, test_labels))

end = time.time()
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 59s 37ms/step - loss: 1.8923 - accuracy: 0.2942 - val_loss: 1.4119 - val_accuracy: 0.4902
# Epoch 2/10
# 1563/1563 [==============================] - 57s 36ms/step - loss: 1.4011 - accuracy: 0.4966 - val_loss: 1.2823 - val_accuracy: 0.5424
# Epoch 3/10
# 1563/1563 [==============================] - 57s 37ms/step - loss: 1.2302 - accuracy: 0.5617 - val_loss: 1.2046 - val_accuracy: 0.5734
# Epoch 4/10
# 1563/1563 [==============================] - 58s 37ms/step - loss: 1.1282 - accuracy: 0.5965 - val_loss: 1.1878 - val_accuracy: 0.5773
# Epoch 5/10
# 1563/1563 [==============================] - 58s 37ms/step - loss: 1.0621 - accuracy: 0.6245 - val_loss: 1.1159 - val_accuracy: 0.6119
# Epoch 6/10
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.9827 - accuracy: 0.6533 - val_loss: 1.1249 - val_accuracy: 0.6104
# Epoch 7/10
# ...

# %%
# test model and print results
print("Validation set results")
test_loss, test_acc = model.evaluate(gauss_test, test_labels, verbose = 2)

# print total time take
minutes = (end - start) / 60
print("Total time taken to classify: {:.2f}".format(minutes), "minutes")

# Plot the accuracy
plt.title("Accuracy")
plt.plot(history.history['accuracy'], label='Test Accuracy')
plt.plot(history.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='upper right')
plt.show()

# Plot the loss
plt.title("Loss")
plt.plot(history.history['loss'], label='Test Loss')
plt.plot(history.history['val_loss'], label = 'Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0.5, 2])
plt.legend(loc='upper right')
plt.show()
# Out:
# Validation set results
# 313/313 - 5s - loss: 1.1439 - accuracy: 0.6191
# Total time taken to classify: 9.74 minutes
